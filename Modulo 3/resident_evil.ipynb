# %%
import pandas as pd
re = pd.read_csv('residentevil.csv')

# %%
re.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4'], dtype='object')

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  182 non-null    int64
#  1   0           182 non-null    object
#  2   1           182 non-null    int64
#  3   2           182 non-null    object
#  4   3           182 non-null    float64
#  5   4           182 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 8.7+ KB

# %%
re.shape
# Out:
# (182, 6)

# %%
re.head(181)
# Out:
#      Unnamed: 0             0   1  \
# 0             0         Izgar   9
# 1             1        Vmac19   6
# 2             2         TomNX   9
# 3             3     Diniandra   9
# 4             4      Radzz202  10
# ..          ...           ...  ..
# 176         176      KayVen17   9
# 177         177    ehsanelite  10
# 178         178   barryburton  10
# 179         179           VTL   9
# 180         180  VirgonoShaka   9
#
#                                                      2         3         4
# 0    Stunning graphics, frightening atmosphere I on... -0.081250  0.683333
# 1    It was okay I guess you had to of been a fan o...  0.215000  0.490000
# 2    Escuridão e úmida excelente para game survial ... -0.400000  0.400000
# 3    Great graphics, awesome gameplay, classic feel...  0.655556  0.638889
# 4    This is a concrete evidence that Capcom has cl...  0.040625  0.675000
# ..                                                 ...       ...       ...
# ...

# %% [markdown]
#  # TABEL DE CLUBES

# %% [markdown]
# # import de pandas/ leitura de csv

# %%
import pandas as pd

# %%
tabc = pd.read_csv("Tabela_Clubes.csv")

# %% [markdown]
# # DATAFRAME

# %%
tabc.head(17)
# Out:
#     Unnamed: 0   Ano  Pos.         Clubes  Vitorias  Derrotas  Empates  \
# 0            0  2017    18     America-MG        10        10       18
# 1            1  2017     7   Athletico-PR        16         9       13
# 2            2  2017     6    Atletico-MG        17         8       13
# 3            3  2017    11          Bahia        12        12       14
# 4            4  2017     9       Botafogo        13        12       13
# 5            5  2017    15          Ceara        10        14       14
# 6            6  2017    14    Chapecoense        11        11       16
# 7            7  2017    13    Corinthians        11        11       16
# 8            8  2017     8       Cruzeiro        14        11       13
# 9            9  2017     2       Flamengo        21         9        8
# 10          10  2017    12     Fluminense        12         9       17
# 11          11  2017     4         Gremio        18        12        8
# ...

# %% [markdown]
# # quantia de linhas e colunas

# %%
tabc.shape
# Out:
# (200, 14)

# %% [markdown]
# # informações da tabela csv

# %%
tabc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     200 non-null    int64
#  1   Ano            200 non-null    int64
#  2   Pos.           200 non-null    int64
#  3   Clubes         200 non-null    object
#  4   Vitorias       200 non-null    int64
#  5   Derrotas       200 non-null    int64
#  6   Empates        200 non-null    int64
#  7   GolsF/S        200 non-null    object
#  8   Saldo          200 non-null    int64
#  9   Qtd_Jogadores  200 non-null    int64
#  10  Idade_Media    200 non-null    object
#  11  Estrangeiros   200 non-null    int64
#  12  Valor_total    200 non-null    int64
#  13  Media_Valor    200 non-null    int64
# dtypes: int64(11), object(3)
# memory usage: 22.0+ KB

# %%
tabc.describe()
# Out:
#        Unnamed: 0          Ano        Pos.    Vitorias    Derrotas  \
# count  200.000000   200.000000  200.000000  200.000000  200.000000
# mean    99.500000  2012.500000   10.500000   13.855000   10.280000
# std     57.879185     2.879489    5.780751    3.967706    2.528551
# min      0.000000  2008.000000    1.000000    4.000000    3.000000
# 25%     49.750000  2010.000000    5.750000   11.000000    9.000000
# 50%     99.500000  2012.500000   10.500000   14.000000   10.000000
# 75%    149.250000  2015.000000   15.250000   16.000000   12.000000
# max    199.000000  2017.000000   20.000000   24.000000   17.000000
#
#           Empates      Saldo  Qtd_Jogadores  Estrangeiros   Valor_total  \
# count  200.000000  200.00000      200.00000    200.000000  2.000000e+02
# mean    13.855000    0.00000       43.23000      2.885000  3.925280e+07
# std      4.187079   15.52725        9.47661      2.042704  2.523390e+07
# min      4.000000  -57.00000       20.00000      0.000000  2.350000e+06
# ...

# %%
tabc.columns
# Out:
# Index(['Unnamed: 0', 'Ano', 'Pos.', 'Clubes', 'Vitorias', 'Derrotas',
#        'Empates', 'GolsF/S', 'Saldo', 'Qtd_Jogadores', 'Idade_Media',
#        'Estrangeiros', 'Valor_total', 'Media_Valor'],
#       dtype='object')

# %%
tabc['Ano'].mean()
# Out:
# np.float64(2012.5)

# %%
tabc[tabc['Ano'] == 2009]['Vitorias']
# Out:
# 160    17
# 161    11
# 162    13
# 163    11
# 164    14
# 165    10
# 166    19
# 167    20
# 168     9
# 169    20
# 170     8
# 171    17
# 172     8
# 173    16
# 174    12
# 175     7
# 176    15
# 177    15
# 178    11
# 179     9
# Name: Vitorias, dtype: int64
